# %% [markdown]
# ### MongoDB Harjoituksia DATA-TYPO2

# %% [markdown]
# 0) Luo yhteys Mongo-kantaasi

# %%
from pymongo import MongoClient
from dotenv import load_dotenv
import pandas as pd
import os
from mongo_connection import connect

def connect():
    try:
        # 
        # client = MongoClient("MONGO")
        global client 
        client = MongoClient("mongodb+srv://oilikalm:mongokokeilu@cluster0.jfqoq.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
        # client = MongoClient(f"mongodb+srv://oilikalm:{('MONGOPASS')}@cluster0.jfqoq.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
        print("connected")
        return client
    except:
        print("no connection")


if __name__== '__main__':
    client = connect()
# Out:
# connected

# %% [markdown]
# 1) Tulosta kaikkien tietokantojesi nimet

# %%
# print(client.list_database_names())
databases= client.list_database_names() # tämä palauttaa nimet listamuodossa
for name in databases:
    print(name)
# Out:
# sample_mflix
# tauko
# admin
# local

# %% [markdown]
# 2) Tulosta kaikki sample_mflix -tietokannan collectionit

# %%
db= client["sample_mflix"]
print(db.list_collection_names())
# Out:
# ['theaters', 'sessions', 'embedded_movies', 'users', 'movies', 'comments']

# %% [markdown]
# 3) Aseta gamesDB-tietokannan games-collection coll-nimiseen muuttujaan

# %%
df = pd.read_csv("metacritic_games.csv")

# Muutetaan dataframe ensin dictionaryksi
data =df.to_dict(orient="records") # orient oletuksena "dict", löytyy myös list, series, split ja index

# luodaan tietokanta (jos ei löydy) tai luodaan uusi kanta (jos ei löydy)
db=client["gamesDB"]

# vastavasti luodaan/käytetään collection ja lisätään siihen data
# coll = db["games"]
# coll.insert_many(data)

# voidaan myös suoraan dataa lisätessä luoda collection
db.games.insert_many(data)
# Out:
# InsertManyResult([ObjectId('673b0636419f8998098f59b4'), ObjectId('673b0636419f8998098f59b5'), ObjectId('673b0636419f8998098f59b6'), ObjectId('673b0636419f8998098f59b7'), ObjectId('673b0636419f8998098f59b8'), ObjectId('673b0636419f8998098f59b9'), ObjectId('673b0636419f8998098f59ba'), ObjectId('673b0636419f8998098f59bb'), ObjectId('673b0636419f8998098f59bc'), ObjectId('673b0636419f8998098f59bd'), ObjectId('673b0636419f8998098f59be'), ObjectId('673b0636419f8998098f59bf'), ObjectId('673b0636419f8998098f59c0'), ObjectId('673b0636419f8998098f59c1'), ObjectId('673b0636419f8998098f59c2'), ObjectId('673b0636419f8998098f59c3'), ObjectId('673b0636419f8998098f59c4'), ObjectId('673b0636419f8998098f59c5'), ObjectId('673b0636419f8998098f59c6'), ObjectId('673b0636419f8998098f59c7'), ObjectId('673b0636419f8998098f59c8'), ObjectId('673b0636419f8998098f59c9'), ObjectId('673b0636419f8998098f59ca'), ObjectId('673b0636419f8998098f59cb'), ObjectId('673b0636419f8998098f59cc'), ObjectId('673b0636419f8998098f59cd'), ObjectId('673b0636419f8998098f59ce'), ObjectId('673b0636419f8998098f59cf'), ObjectId('673b0636419f8998098f59d0'), ObjectId('673b0636419f8998098f59d1'), ObjectId('673b0636419f8998098f59d2'), ObjectId('673b0636419f8998098f59d3'), ObjectId('673b0636419f8998098f59d4'), ObjectId('673b0636419f8998098f59d5'), ObjectId('673b0636419f8998098f59d6'), ObjectId('673b0636419f8998098f59d7'), ObjectId('673b0636419f8998098f59d8'), ObjectId('673b0636419f8998098f59d9'), ObjectId('673b0636419f8998098f59da'), ObjectId('673b0636419f8998098f59db'), ObjectId('673b0636419f8998098f59dc'), ObjectId('673b0636419f8998098f59dd'), ObjectId('673b0636419f8998098f59de'), ObjectId('673b0636419f8998098f59df'), ObjectId('673b0636419f8998098f59e0'), ObjectId('673b0636419f8998098f59e1'), ObjectId('673b0636419f8998098f59e2'), ObjectId('673b0636419f8998098f59e3'), ObjectId('673b0636419f8998098f59e4'), ObjectId('673b0636419f8998098f59e5'), ObjectId('673b0636419f8998098f59e6'), ObjectId('673b0636419f8998098f59e7'), ObjectId('673b0636419f8998098f59e8'), ObjectId('673b0636419f8998098f59e9'), ObjectId('673b0636419f8998098f59ea'), ObjectId('673b0636419f8998098f59eb'), ObjectId('673b0636419f8998098f59ec'), ObjectId('673b0636419f8998098f59ed'), ObjectId('673b0636419f8998098f59ee'), ObjectId('673b0636419f8998098f59ef'), ObjectId('673b0636419f8998098f59f0'), ObjectId('673b0636419f8998098f59f1'), ObjectId('673b0636419f8998098f59f2'), ObjectId('673b0636419f8998098f59f3'), ObjectId('673b0636419f8998098f59f4'), ObjectId('673b0636419f8998098f59f5'), ObjectId('673b0636419f8998098f59f6'), ObjectId('673b0636419f8998098f59f7'), ObjectId('673b0636419f8998098f59f8'), ObjectId('673b0636419f8998098f59f9'), ObjectId('673b0636419f8998098f59fa'), ObjectId('673b0636419f8998098f59fb'), ObjectId('673b0636419f8998098f59fc'), ObjectId('673b0636419f8998098f59fd'), ObjectId('673b0636419f8998098f59fe'), ObjectId('673b0636419f8998098f59ff'), ObjectId('673b0636419f8998098f5a00'), ObjectId('673b0636419f8998098f5a01'), ObjectId('673b0636419f8998098f5a02'), ObjectId('673b0636419f8998098f5a03'), ObjectId('673b0636419f8998098f5a04'), ObjectId('673b0636419f8998098f5a05'), ObjectId('673b0636419f8998098f5a06'), ObjectId('673b0636419f8998098f5a07'), ObjectId('673b0636419f8998098f5a08'), ObjectId('673b0636419f8998098f5a09'), ObjectId('673b0636419f8998098f5a0a'), ObjectId('673b0636419f8998098f5a0b'), ObjectId('673b0636419f8998098f5a0c'), ObjectId('673b0636419f8998098f5a0d'), ObjectId('673b0636419f8998098f5a0e'), ObjectId('673b0636419f8998098f5a0f'), ObjectId('673b0636419f8998098f5a10'), ObjectId('673b0636419f8998098f5a11'), ObjectId('673b0636419f8998098f5a12'), ObjectId('673b0636419f8998098f5a13'), ObjectId('673b0636419f8998098f5a14'), ObjectId('673b0636419f8998098f5a15'), ObjectId('673b0636419f8998098f5a16'), ObjectId('673b0636419f8998098f5a17'), ObjectId('673b0636419f8998098f5a18'), ObjectId('673b0636419f8998098f5a19'), ObjectId('673b0636419f8998098f5a1a'), ObjectId('673b0636419f8998098f5a1b'), ObjectId('673b0636419f8998098f ...

# %% [markdown]
# coll.find({"name": "limbo"})

# %% [markdown]
# 4. Hae games-collectionista 5 ensimmäistä tietuetta ja tulosta niiden game-kentän arvo (pelin nimi)

# %%
db= client["gamesDB"]
print(db.list_collection_names())
coll = db["games"]
myresult = coll.find().limit(5)

#print the result:
for x in myresult:
  print(x["game"])
# Out:
# ['games']
# Portal 2
# The Elder Scrolls V: Skyrim
# The Legend of Zelda: Ocarina of Time 3D
# Batman: Arkham City
# Super Mario 3D Land

# %% [markdown]
# 5. (Käytetään gamesDB-tietokantaa ja games-collectionia)
# Tulosta kaikki tulokset, joissa pelin nimi (game-kentän arvo) on LIMBO

# %%
myresult = coll.find({"game":"LIMBO"}) # .limit(1) # ja vaikka ({"game": "LIMBO"})"platfrom": "PC"})
for x in myresult:
    print(x)
# Out:
# {'_id': ObjectId('673b0636419f8998098f59be'), 'game': 'LIMBO', 'platform': 'PC', 'developer': 'PLAYDEAD', 'genre': 'Action', 'number_players': 'No Online Multiplayer', 'rating': 'T', 'release_date': 'Aug  2, 2011', 'positive_critics': 22, 'neutral_critics': 0, 'negative_critics': 0, 'positive_users': 190, 'neutral_users': 63, 'negative_users': 25, 'metascore': 88, 'user_score': 81}
# {'_id': ObjectId('673b0636419f8998098f6be8'), 'game': 'LIMBO', 'platform': 'Switch', 'developer': 'PLAYDEAD', 'genre': 'Action', 'number_players': 'No Online Multiplayer', 'rating': 'T', 'release_date': 'Jun 28, 2018', 'positive_critics': 20, 'neutral_critics': 7, 'negative_critics': 0, 'positive_users': 5, 'neutral_users': 0, 'negative_users': 0, 'metascore': 83, 'user_score': 83}

# %% [markdown]
# 6. Importtaa pprint-moduli, ja käytä siitä pprint-metodia tulostaaksesi 5.tehtävään ensimmäinen tulos

# %%
# import pprint as pp

# %% [markdown]
# 7. Tulosta games-collectionin dokumenttien määrä (5699)

# %% [markdown]
# 8. Tulosta, kuinka monen games-collectionin dokumentin platform on "PC" (2138)

# %% [markdown]
# 9. Tulosta kaikki games-collectionin dokumentit, joiden game-kentässä on teksti "skyrim" (case-sensitiivisyys ignorataan)

# %% [markdown]
# 10. Hae games-collectionista kaikki pelit, joiden nimi alkaa "Battle" ja tulosta tulosten määrä (42 kpl)

# %% [markdown]
# 11. Hae games-collectionista kaikki pelit, joiden nimessä on "field" ja tulosta niiden määrä (21 kpl)

# %% [markdown]
# 12. Hae games-collectionista kaikki pelit, joiden nimi päättyy "12" ja tulosta niiden määrä (11 kpl)

# %% [markdown]
# 13. Hae games-collectionista kaikki dokumentit ja tulosta niiden pelien nimet(ei duplikaatteja!), joiden metascore on vähintään 95

# %% [markdown]
# 10. Use Mongo Atlas GUI with browser to browse *cities* collection. Choose one ObjectId, and fetch record, which has that ObjectId

# %% [markdown]
# 12. Hae ja tulosta games-collectionista kaikkien pelien nimet, platformit ja user_scoret; joiden nimessä on "wit, ja joiden user_score on 90-92 -välissä, user_score sortattuna isoimmasta pienimpään (5 tulosta)

# %% [markdown]
# 13. Create a list, which includes "LIMBO" and "Skyrim". Make a query, that will find both games from games-collection (tip:use regex and $or )

# %% [markdown]
# 14. Change db to citiesDB.  Print all **distinct** *countries* which has a *country* field starting with "Fi"

# %% [markdown]
# 15. Fetch all *cities* ending with "enki", and sort results so, that results are printed alphabetically reversed.

# %% [markdown]
# 16. . Fetch all cities in *country* Finland, ending with "nki", and sort results alphabetically

# %% [markdown]
# 17. Fetch first 10 cities, where *city* field has a population with a value at least 5 millions, sorted from biggest population to smallest

# %% [markdown]
# 18. Fetch first 10 cities, where *city* field has a population with at least 5 millions.
# This time use *aggregate* method to make three-phase stages with query.
# First stage: use *match* to find cities with population greater or equal to 5 millions
# Second stage: use sort to sort by population (from biggest to smallest) and
# Third stage: then limiting results to first 10. Now you should see same cities as in exercise 17, but using aggregate instead of find.

# %% [markdown]
# 19. Fetch the same cities and populations as in exercises 17 and 18, but this time sort results by city name.
# Tip: You can create list, and insert cities and populations to list while iterating results. Then you can sort list.

# %% [markdown]
# 20. Modify previous exercise so, that you sort results by the length of the city name (longest first). Also include population after city name

# %% [markdown]
# 21. Find out how to sort by string length in MongoDB. Fetch all cities and city name lengths in descending order for cities with population equal or over 5 millions, and limit results to 10.

# %% [markdown]
# 22. Find 10 longest city names of *cities* collection, with city name, country and city name length

# %% [markdown]
# 23. Change database to **sample_mflix** and use collection **movies**

# %% [markdown]
# 24. Find all movies with imdb rating more or equal to 8.5. Sort results from best imdb rating to lower.

# %% [markdown]
# 25. Modify exercise 24 sorting so, that results will show movies rated with at least imdb rating 9.0 or rating 3.0 or lower

# %% [markdown]
# 26. Fetch all movies having exact rating 9.0 and having Tom Hanks listed in cast
